# %%
import pandas as pd
import pygwalker as pyg
import os
print(os.getcwd())


# 读取你的Excel数据，注意sheet名和路径
# df = pd.read_excel(r'F:\kabuda_data_nalysis\excel\司机全量模块化数据输出.xlsx', sheet_name='司机全量档案')
df = pd.read_excel(r'F:\kabuda_data_nalysis\excel\司机全量模块化数据输出.xlsx', sheet_name='地区分布统计_司机')


# 启动交互式可视化
pyg.walk(df)


pyg.to_html(df, r'F:\kabuda_data_nalysis\output_pygwalker.html')
# Out:
# F:\kabuda_data_nalysis
# Box(children=(HTML(value='\n<div id="ifr-pyg-00063602c0731e2fWRebfSMdB6vcULCD" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "00063602c0731e2fWRebfSMdB6vcULCD") {
#             var iframe = document.getElementById("gwalker-00063602c0731e2fWRebfSMdB6vcULCD");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>

# %%
file_path = r'F:\kabuda_data_nalysis\output_pygwalker.html'
pyg.to_html(df, file_path)

if os.path.exists(file_path):
    print("文件生成成功！大小：", os.path.getsize(file_path), "字节")
else:
    print("未找到文件，生成失败！")
# Out:
# 未找到文件，生成失败！
